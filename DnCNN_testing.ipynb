# %% [markdown]
# # **Testing of the DnCNN model**
#
# This test is based on the paper :
#
# ```
# @article{zhang2017beyond,
#     title={Beyond a {Gaussian} denoiser: Residual learning of deep {CNN} for image denoising},
#     author={Zhang, Kai and Zuo, Wangmeng and Chen, Yunjin and Meng, Deyu and Zhang, Lei},
#     journal={IEEE Transactions on Image Processing},
#     year={2017},
#     volume={26},
#     number={7},
#     pages={3142-3155},
#   }
# ```
# And, the implementation is majorly based on: [https://github.com/cszn/DnCNN/blob/master/TrainingCodes/dncnn_keras/main_test.py](https://github.com/cszn/DnCNN/blob/master/TrainingCodes/dncnn_keras/main_test.py)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Patch Generator

# %% [markdown]
# The function ```gen_patch(img_list, noise_level)``` takes the list of all testing images with specific noise level to form set of noisy and clean patches. Moreover, it also returns the patch position in order to retrieve the patches in original image

# %%
import cv2
import numpy as np
import glob

def gen_patch(img_list, noise_level):
    Patch = []
    Noisy_Patch = []
    Patch_position = []
    patch_size = 50
    stride = 50
    n = len(img_list)
    print(n)
    for i in range(n):
        img = cv2.imread(img_list[i])
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        for p in range(0, img.shape[0] - patch_size+1, stride):
            for q in range(0, img.shape[1] - patch_size+1, stride):
                height_slice = slice(p, p+patch_size)
                width_slice = slice(q, q+patch_size)
                pos = (i, p, q)
                Patch_position.append(pos)
                patch = img[height_slice, width_slice, :]
                AWG_noise = np.random.normal(0.0, noise_level/255.0, patch.shape)
                noisyImg_patch = patch/255.0 + AWG_noise
                noisyImg_patch.astype(np.float32)
                Target_patch = patch/255.0
                Target_patch.astype(np.float32)
                Patch.append(Target_patch) 
                Noisy_Patch.append(noisyImg_patch)         
                
    return np.array(Patch), np.array(Noisy_Patch), np.array(Patch_position)

# %% [markdown]
# ## Noisy Patches

# %% [markdown]
# Forming noisy patches from set of patches in **CBSD68 test dataset**.

# %%
test_path = '/content/drive/My Drive/CBSD68'
test_file_list = glob.glob(test_path+'/*.jpg') 
Noise_Level = [10, 20, 30, 40, 50]  # Noise level for testing on difeerent values
Patch, Noisy_patch10, Patch_position = gen_patch(test_file_list, Noise_Level[0])
_, Noisy_patch20, _ = gen_patch(test_file_list, Noise_Level[1])
_, Noisy_patch30, _ = gen_patch(test_file_list, Noise_Level[2])
_, Noisy_patch40, _ = gen_patch(test_file_list, Noise_Level[3])
_, Noisy_patch50, _ = gen_patch(test_file_list, Noise_Level[4])
# Out:
# 68
# 68
# 68
# 68
# 68

# %%
print(test_file_list)
# Out:
# ['/content/drive/My Drive/CBSD68/105025.jpg', '/content/drive/My Drive/CBSD68/106024.jpg', '/content/drive/My Drive/CBSD68/101085.jpg', '/content/drive/My Drive/CBSD68/103070.jpg', '/content/drive/My Drive/CBSD68/102061.jpg', '/content/drive/My Drive/CBSD68/101087.jpg', '/content/drive/My Drive/CBSD68/109053.jpg', '/content/drive/My Drive/CBSD68/143090.jpg', '/content/drive/My Drive/CBSD68/134035.jpg', '/content/drive/My Drive/CBSD68/12084.jpg', '/content/drive/My Drive/CBSD68/108082.jpg', '/content/drive/My Drive/CBSD68/148026.jpg', '/content/drive/My Drive/CBSD68/16077.jpg', '/content/drive/My Drive/CBSD68/157055.jpg', '/content/drive/My Drive/CBSD68/14037.jpg', '/content/drive/My Drive/CBSD68/119082.jpg', '/content/drive/My Drive/CBSD68/108005.jpg', '/content/drive/My Drive/CBSD68/126007.jpg', '/content/drive/My Drive/CBSD68/147091.jpg', '/content/drive/My Drive/CBSD68/123074.jpg', '/content/drive/My Drive/CBSD68/148089.jpg', '/content/drive/My Drive/CBSD68/160068.jpg', '/content/drive/My Drive/CBSD68/108070.jpg', '/content/drive/My Drive/CBSD68/145086.jpg', '/content/drive/My Drive/CBSD68/130026.jpg', '/content/drive/My Drive/CBSD68/159008.jpg', '/content/drive/My Drive/CBSD68/19021.jpg', '/content/drive/My Drive/CBSD68/223061.jpg', '/content/drive/My Drive/CBSD68/208001.jpg', '/content/drive/My Drive/CBSD68/220075.jpg', '/content/drive/My Drive/CBSD68/163085.jpg', '/content/drive/My Drive/CBSD68/21077.jpg', '/content/drive/My Drive/CBSD68/167062.jpg', '/content/drive/My Drive/CBSD68/175043.jpg', '/content/drive/My Drive/CBSD68/170057.jpg', '/content/drive/My Drive/CBSD68/210088.jpg', '/content/drive/My Drive/CBSD68/182053.jpg', '/content/drive/My Drive/CBSD68/219090.jpg', '/content/drive/My Drive/CBSD68/189080.jpg', '/content/drive/My Drive/CBSD68/197017.jpg', '/content/drive/My Drive/CBSD68/196073.jpg', '/content/drive/My Drive/CBSD68/216081.jpg', '/content/drive/My Drive/CBSD68/175032.jpg', '/content/drive/My Drive/CBSD68/167083.jpg', '/content/drive/My Drive/CBSD68/24077.jpg', '/content/drive/My Drive/CBSD68/285079.jpg', '/content/drive/My Drive/CBSD68/227092.jpg', '/content/drive/My Drive/CBSD68/295087.jpg', '/content/drive/My Drive/CBSD68/260058.jpg', '/content/drive/My Drive/CBSD68/229036.jpg', '/content/drive/My Drive/CBSD68/271035.jpg', '/content/drive/My Drive/CBSD68/241048.jpg', '/content/drive/My Drive/CBSD68/241004.jpg', '/content/drive/My Drive/CBSD68/253055.jpg', '/content/drive/My Drive/CBSD68/296007.jpg', '/content/drive/My Drive/CBSD68/299086.jpg', '/content/drive/My Drive/CBSD68/291000.jpg', '/content/drive/My Drive/CBSD68/296059.jpg', '/content/drive/My Drive/CBSD68/236037.jpg', '/content/drive/My Drive/CBSD68/253027.jpg', '/content/drive/My Drive/CBSD68/304074.jpg', '/content/drive/My Drive/CBSD68/300091.jpg', '/content/drive/My Drive/CBSD68/306005.jpg', '/content/drive/My Drive/CBSD68/3096.jpg', '/content/drive/My Drive/CBSD68/302008.jpg', '/content/drive/My Drive/CBSD68/33039.jpg', '/content/drive/My Drive/CBSD68/351093.jpg', '/content/drive/My Drive/CBSD68/304034.jpg']

# %% [markdown]
# ## Testing Model

# %%
from keras.models import load_model
import time, math
import tensorflow as tf
import matplotlib.pyplot as plt
from skimage.measure import compare_ssim

# %%
def PSNR(y_true, y_pred):
    return tf.image.psnr(y_true, y_pred, max_val=1)

def mse_loss(y_true, y_pred):
    err = y_true - y_pred
    mse = K.sum(err*err)/(2*batch_size)
    return mse

# %% [markdown]
# Here, we are retrieving the trained model for denoising of natural images

# %%
path = '/content/drive/My Drive/BSR_bsds500/log_DnCNN/exp-50*50_20st'
# Name experiment
experiment_name = "exp-50*50_20st"
model = load_model('{}/{}.h5'.format(path, experiment_name), custom_objects={'mse_loss': mse_loss,'PSNR': PSNR})

# %% [markdown]
# The function ```predict_image(clean_patch, Noisy_patch, model)``` takes the patches of CBSD68 test set, corresponding noisy patch and trained model. It prints the time taken for one patch prediction and gives predicted output image, corresponding PSNR(dB) & SSIM.

# %%
def predict_image(clean_patch, Noisy_patch, model):
  psnr = []
  predimg = []
  ssim = []
  for i in range(Noisy_patch.shape[0]):
    noise_patch = np.expand_dims(Noisy_patch[i], axis=0)
    start_time = time.time()
    pred = model.predict(noise_patch)
    end_time = time.time()
    
    pred_image = pred.squeeze()
    pred_image.astype(np.float32)
    predimg.append(pred_image)
    psnr.append(PSNR(clean_patch[i], pred_image))
    ssim.append(compare_ssim(clean_patch[i], pred_image, multichannel=True))

  print('One set complete')
  print("--- Time taken to predict 1 patch: %s seconds ---" % (end_time - start_time))  
 
  return np.array(predimg), np.array(psnr), np.array(ssim)

# %% [markdown]
# Denoising of Image, PSNR & SSIM for each noise level.

# %%
pred10, psnr10, ssim10 = predict_image(Patch, Noisy_patch10, model)
pred20, psnr20, ssim20 = predict_image(Patch, Noisy_patch20, model)
pred30, psnr30, ssim30 = predict_image(Patch, Noisy_patch30, model)
pred40, psnr40, ssim40 = predict_image(Patch, Noisy_patch40, model)
pred50, psnr50, ssim50 = predict_image(Patch, Noisy_patch50, model)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: UserWarning: DEPRECATED: skimage.measure.compare_ssim has been moved to skimage.metrics.structural_similarity. It will be removed from skimage.measure in version 0.18.
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.6/dist-packages/skimage/metrics/_structural_similarity.py:108: UserWarning: Inputs have mismatched dtype.  Setting data_range based on im1.dtype.
#   im2[..., ch], **args)
# One set complete
# --- Time taken to predict 1 patch: 0.03174161911010742 seconds ---
# One set complete
# --- Time taken to predict 1 patch: 0.03332638740539551 seconds ---
# One set complete
# --- Time taken to predict 1 patch: 0.028554439544677734 seconds ---
# One set complete
# --- Time taken to predict 1 patch: 0.03576159477233887 seconds ---
# One set complete
# --- Time taken to predict 1 patch: 0.03318977355957031 seconds ---

# %%
print("Total Patches: %2.0f" %(len(pred10)))
# Out:
# Total Patches: 3672

# %% [markdown]
# ## Average PSNR and SSIM Value

# %%
print(" Average PSNR(dB)/SSIM for sigma = 10: %2.2f/%2.4f" %(np.mean(psnr10),np.mean(ssim10)))
print(" Average PSNR(dB)/SSIM for sigma = 20: %2.2f/%2.4f" %(np.mean(psnr20),np.mean(ssim20)))
print(" Average PSNR(dB)/SSIM for sigma = 30: %2.2f/%2.4f" %(np.mean(psnr30),np.mean(ssim30)))
print(" Average PSNR(dB)/SSIM for sigma = 40: %2.2f/%2.4f" %(np.mean(psnr40),np.mean(ssim40)))
print(" Average PSNR(dB)/SSIM for sigma = 50: %2.2f/%2.4f" %(np.mean(psnr50),np.mean(ssim50)))
# Out:
#  Average PSNR(dB)/SSIM for sigma = 10: 32.77/0.9464
#  Average PSNR(dB)/SSIM for sigma = 20: 30.27/0.9221
#  Average PSNR(dB)/SSIM for sigma = 30: 26.65/0.8249
#  Average PSNR(dB)/SSIM for sigma = 40: 23.76/0.7003
#  Average PSNR(dB)/SSIM for sigma = 50: 21.37/0.5808

# %% [markdown]
# ## Predicted Visualization

# %%
from matplotlib import patches

# %% [markdown]
# ### For Noise level: $\sigma$ = 10

# %%
f1, axarr1 = plt.subplots(1,1)
f, axarr = plt.subplots(1,3)
i = 450
(img_num, p, q) = Patch_position[i]
img = cv2.imread(test_file_list[img_num])
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
rect = patches.Rectangle((q, p), 50, 50, edgecolor ='r', facecolor = 'none')

axarr1.imshow(img)
axarr1.add_patch(rect)
axarr1.title.set_text('Original Image')

axarr[0].imshow(Patch[i])
axarr[0].title.set_text('Extracted Patch')
axarr[1].imshow(Noisy_patch10[i])
axarr[1].title.set_text('Noisy Patch ($\sigma$ = 10)')
axarr[2].imshow(pred10[i])
axarr[2].title.set_text('Cleaned Patch')
print("PSNR: %s" % psnr10[i])
print("SSIM: %s" % ssim10[i])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# PSNR: 33.005245
# SSIM: 0.9575883869833376

# %% [markdown]
# ### For Noise level: $\sigma$ = 20

# %%
f1, axarr1 = plt.subplots(1,1)
f, axarr = plt.subplots(1,3)
i = 450
(img_num, p, q) = Patch_position[i]
img = cv2.imread(test_file_list[img_num])
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
rect = patches.Rectangle((q, p), 50, 50, edgecolor ='r', facecolor = 'none')

axarr1.imshow(img)
axarr1.add_patch(rect)
axarr1.title.set_text('Original Image')

axarr[0].imshow(Patch[i])
axarr[0].title.set_text('Extracted Patch')
axarr[1].imshow(Noisy_patch20[i])
axarr[1].title.set_text('Noisy Patch ($\sigma$ = 20)')
axarr[2].imshow(pred20[i])
axarr[2].title.set_text('Cleaned Patch')
print("PSNR: %s" % psnr20[i])
print("SSIM: %s" % ssim20[i])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# PSNR: 30.442486
# SSIM: 0.9354135495711325

# %% [markdown]
# ### For Noise level: $\sigma$ = 30

# %%
f1, axarr1 = plt.subplots(1,1)
f, axarr = plt.subplots(1,3)
i = 450
(img_num, p, q) = Patch_position[i]
img = cv2.imread(test_file_list[img_num])
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
rect = patches.Rectangle((q, p), 50, 50, edgecolor ='r', facecolor = 'none')

axarr1.imshow(img)
axarr1.add_patch(rect)
axarr1.title.set_text('Original Image')

axarr[0].imshow(Patch[i])
axarr[0].title.set_text('Extracted Patch')
axarr[1].imshow(Noisy_patch30[i])
axarr[1].title.set_text('Noisy Patch ($\sigma$ = 30)')
axarr[2].imshow(pred30[i])
axarr[2].title.set_text('Cleaned Patch')
print("PSNR: %s" % psnr30[i])
print("SSIM: %s" % ssim30[i])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# PSNR: 27.10403
# SSIM: 0.8671095265699185

# %% [markdown]
# ### For Noise level: $\sigma$ = 40

# %%
f1, axarr1 = plt.subplots(1,1)
f, axarr = plt.subplots(1,3)
i = 450
(img_num, p, q) = Patch_position[i]
img = cv2.imread(test_file_list[img_num])
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
rect = patches.Rectangle((q, p), 50, 50, edgecolor ='r', facecolor = 'none')

axarr1.imshow(img)
axarr1.add_patch(rect)
axarr1.title.set_text('Original Image')

axarr[0].imshow(Patch[i])
axarr[0].title.set_text('Extracted Patch')
axarr[1].imshow(Noisy_patch40[i])
axarr[1].title.set_text('Noisy Patch ($\sigma$ = 40)')
axarr[2].imshow(pred40[i])
axarr[2].title.set_text('Cleaned Patch')
print("PSNR: %s" % psnr40[i])
print("SSIM: %s" % ssim40[i])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# PSNR: 23.851402
# SSIM: 0.7528913430706864

# %% [markdown]
# ### For Noise level: $\sigma$ = 50

# %%
f1, axarr1 = plt.subplots(1,1)
f, axarr = plt.subplots(1,3)
i = 450
(img_num, p, q) = Patch_position[i]
img = cv2.imread(test_file_list[img_num])
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
rect = patches.Rectangle((q, p), 50, 50, edgecolor ='r', facecolor = 'none')

axarr1.imshow(img)
axarr1.add_patch(rect)
axarr1.title.set_text('Original Image')

axarr[0].imshow(Patch[i])
axarr[0].title.set_text('Extracted Patch')
axarr[1].imshow(Noisy_patch50[i])
axarr[1].title.set_text('Noisy Patch ($\sigma$ = 50)')
axarr[2].imshow(pred50[i])
axarr[2].title.set_text('Cleaned Patch')
print("PSNR: %s" % psnr50[i])
print("SSIM: %s" % ssim50[i])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# PSNR: 21.641703
# SSIM: 0.6490294599132511
